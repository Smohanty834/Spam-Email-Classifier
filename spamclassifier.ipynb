# %%
import numpy as np
import pandas as pd

# %%
import chardet
with open("spam.csv", "rb") as f:
    result = chardet.detect(f.read())
df = pd.read_csv("spam.csv", encoding=result['encoding'])

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 4431  ham  Dont think you need yellow card for uk travel....        NaN
# 1176  ham  Did he say how fantastic I am by any chance, o...        NaN
# 4335  ham  Fyi I'm taking a quick shower, be at epsilon i...        NaN
# 5488  ham                            K. I will sent it again        NaN
# 1736  ham                            I will come tomorrow di        NaN
#
#      Unnamed: 3 Unnamed: 4
# 4431        NaN        NaN
# 1176        NaN        NaN
# 4335        NaN        NaN
# 5488        NaN        NaN
# 1736        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 5424   ham  U horrible gal... U knew dat i was going out w...
# 999    ham          Aight will do, thanks again for comin out
# 591   spam  You have been specially selected to receive a ...
# 3891  spam  URGENT This is our 2nd attempt to contact U. Y...
# 1181   ham                         You flippin your shit yet?

# %%
df.rename(columns={'v1':'Target','v2':'Text'},inplace=True)

# %%
df.sample(5)
# Out:
#      Target                                               Text
# 4800    ham  The guy at the car shop who was flirting with ...
# 868    spam  Hello. We need some posh birds and chaps to us...
# 4604    ham  I need an 8th but I'm off campus atm, could I ...
# 4670    ham  Probably not, I'm almost out of gas and I get ...
# 4124    ham  May b approve panalam...but it should have mor...

# %%
#object to integer conv
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['Target']=encoder.fit_transform(df['Target'])

# %%
df.head()
# Out:
#    Target                                               Text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
#missing values check
df.isnull().sum()
# Out:
# Target    0
# Text      0
# dtype: int64

# %%
## check duplicates
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## EDA

# %%
df['Target'].value_counts()
# Out:
# Target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['Target'].value_counts(), labels=['ham','spam'],autopct='%0.2f')
plt.show()

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sm315\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df['num_chars']=df['Text'].apply(len)
# Out:
# C:\Users\sm315\AppData\Local\Temp\ipykernel_3012\3177916126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_chars']=df['Text'].apply(len)

# %%
df.head()
# Out:
#    Target                                               Text  num_chars
# 0       0  Go until jurong point, crazy.. Available only ...        111
# 1       0                      Ok lar... Joking wif u oni...         29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3       0  U dun say so early hor... U c already then say...         49
# 4       0  Nah I don't think he goes to usf, he lives aro...         61

# %%
df['num_words']=df['Text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# C:\Users\sm315\AppData\Local\Temp\ipykernel_3012\675848441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words']=df['Text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df['num_sent']=df['Text'].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# C:\Users\sm315\AppData\Local\Temp\ipykernel_3012\2135583313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sent']=df['Text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    Target                                               Text  num_chars  \
# 0       0  Go until jurong point, crazy.. Available only ...        111
# 1       0                      Ok lar... Joking wif u oni...         29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3       0  U dun say so early hor... U c already then say...         49
# 4       0  Nah I don't think he goes to usf, he lives aro...         61
#
#    num_words  num_sent
# 0         24         2
# 1          8         2
# 2         37         2
# 3         13         1
# 4         15         1

# %%
df[df['Target'] == 0][['num_chars','num_words','num_sent']].describe()
# Out:
#          num_chars    num_words     num_sent
# count  4516.000000  4516.000000  4516.000000
# mean     70.459256    17.123782     1.820195
# std      56.358207    13.493970     1.383657
# min       2.000000     1.000000     1.000000
# 25%      34.000000     8.000000     1.000000
# 50%      52.000000    13.000000     1.000000
# 75%      90.000000    22.000000     2.000000
# max     910.000000   220.000000    38.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.histplot(df[df['Target'] == 0]['num_chars'])
sns.histplot(df[df['Target'] == 1]['num_chars'],color='red')
# Out:
# <Axes: xlabel='num_chars', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['Target'] == 0]['num_words'])
sns.histplot(df[df['Target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='Target')

# %% [markdown]
# ## Data Preprocessing

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
            
    return " ".join(y)

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sm315\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
import string

# %%
df['transformed_text'] = df['Text'].apply(transform_text)
# Out:
# C:\Users\sm315\AppData\Local\Temp\ipykernel_3012\1893880433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['transformed_text'] = df['Text'].apply(transform_text)

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')
spam_wc = wc.generate(df[df['Target'] == 1]['transformed_text'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from wordcloud) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sm315\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp311-cp311-win_amd64.whl (299 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
ham_wc = wc.generate(df[df['Target'] == 0]['transformed_text'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    Target                                               Text  num_chars  \
# 0       0  Go until jurong point, crazy.. Available only ...        111
# 1       0                      Ok lar... Joking wif u oni...         29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3       0  U dun say so early hor... U c already then say...         49
# 4       0  Nah I don't think he goes to usf, he lives aro...         61
#
#    num_words  num_sent                                   transformed_text
# 0         24         2  go jurong point crazi avail bugi n great world...
# 1          8         2                              ok lar joke wif u oni
# 2         37         2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13         1                u dun say earli hor u c alreadi say
# 4         15         1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df['Target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
ham_corpus = []
for msg in df[df['Target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
df.head()
# Out:
#    Target                                               Text  num_chars  \
# 0       0  Go until jurong point, crazy.. Available only ...        111
# 1       0                      Ok lar... Joking wif u oni...         29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...        155
# 3       0  U dun say so early hor... U c already then say...         49
# 4       0  Nah I don't think he goes to usf, he lives aro...         61
#
#    num_words  num_sent                                   transformed_text
# 0         24         2  go jurong point crazi avail bugi n great world...
# 1          8         2                              ok lar joke wif u oni
# 2         37         2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13         1                u dun say earli hor u c alreadi say
# 4         15         1               nah think goe usf live around though

# %% [markdown]
# ## Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
y = df['Target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
